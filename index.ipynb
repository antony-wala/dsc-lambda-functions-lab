# %% [markdown]
# # Lambda Functions - Lab
#
# ## Introduction
#
# In this lab, you'll get some hands-on practice creating and using lambda functions.
#
# ## Objectives
#
# In this lab you will:
#
# * Create lambda functions to use as arguments of other functions
# * Use the `.map()` or `.apply()` method to apply a function to a pandas series or DataFrame

# %% [markdown]
# ## Lambda Functions

# %%
import pandas as pd
df = pd.read_csv('Yelp_Reviews.csv', index_col=0)
df.head(2)
# Out:
#               business_id  cool        date  funny               review_id  \
# 1  pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13      0  dDl8zu1vWPdKGihJrwQbpw
# 2  jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23      1  LZp4UX5zK3e-c5ZGSeo3kA
#
#    stars                                               text  useful  \
# 1      5  I love this place! My fiance And I go here atl...       0
# 2      1  Terrible. Dry corn bread. Rib tips were all fa...       3
#
#                   user_id
# 1  msQe1u7Z_XuqjGoqhB0J5g
# 2  msQe1u7Z_XuqjGoqhB0J5g

# %% [markdown]
# ## Simple arithmetic
#
# Use a lambda function to create a new column called `'stars_squared'` by squaring the stars column.

# %%
# Your code here
df['stars_squared'] = df['stars'].map(lambda x: x**2)

# %%
df.head()
# Out:
#                business_id  cool        date  funny               review_id  \
# 1   pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13      0  dDl8zu1vWPdKGihJrwQbpw
# 2   jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23      1  LZp4UX5zK3e-c5ZGSeo3kA
# 4   Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05      0  jsDu6QEJHbwP2Blom1PLCA
# 5   vgfcTvK81oD4r50NMjU2Ag     0  2011-02-25      0  pfavA0hr3nyqO61oupj-lA
# 10  yFumR3CWzpfvTH2FCthvVw     0  2016-06-15      0  STiFMww2z31siPY7BWNC2g
#
#     stars                                               text  useful  \
# 1       5  I love this place! My fiance And I go here atl...       0
# 2       1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 4       5  Delicious healthy food. The steak is amazing. ...       0
# 5       1  This place sucks. The customer service is horr...       2
# 10      5  I have been an Emerald Club member for a numbe...       0
#
#                    user_id  stars_squared
# 1   msQe1u7Z_XuqjGoqhB0J5g             25
# 2   msQe1u7Z_XuqjGoqhB0J5g              1
# 4   msQe1u7Z_XuqjGoqhB0J5g             25
# 5   msQe1u7Z_XuqjGoqhB0J5g              1
# 10  TlvV-xJhmh7LCwJYXkV-cg             25

# %% [markdown]
# ## Dates
# Select the month from the date string using a lambda function.

# %%
# Your code here

# %% [markdown]
# ## What is the average number of words for a yelp review?
# Do this with a single line of code.

# %%
# Your code here
df['text'].map(lambda x: len(x.strip())).mean()
# Out:
# 417.911877394636

# %% [markdown]
# ## Create a new column for the number of words in the review

# %%
# Your code here
df['no_of_words'] = df['text'].map(lambda x: len(x.strip()))

# %%
df
# Out:
#                  business_id  cool        date  funny               review_id  \
# 1     pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13      0  dDl8zu1vWPdKGihJrwQbpw
# 2     jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23      1  LZp4UX5zK3e-c5ZGSeo3kA
# 4     Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05      0  jsDu6QEJHbwP2Blom1PLCA
# 5     vgfcTvK81oD4r50NMjU2Ag     0  2011-02-25      0  pfavA0hr3nyqO61oupj-lA
# 10    yFumR3CWzpfvTH2FCthvVw     0  2016-06-15      0  STiFMww2z31siPY7BWNC2g
# ...                      ...   ...         ...    ...                     ...
# 689   BTcY04QFiS1uh-RpkR7rAg     1  2013-06-02      0  6_A58CCY8SHB7r-Wu7-A5g
# 4874  t0T_4MM4EUHbCzBTF11FHA     0  2016-08-14      0  KqQwNyfoFiJOw911mrULIg
# 564   5XYR6doRa5Nj1JMfSDei6A     1  2016-06-14      0  xlGJkxoIBl8XH8wVsPZpnw
# 3458  aLcFhMe6DDJ430zelCpd2A     0  2013-10-02      0  kwiEG_KCpDB6aK5fTSM7iw
# 4206  WdBWhGe4Siqg3IYTc4_K4A     0  2016-08-15      0  O0ttxNGxHKtD8Cnnwc_j1g
#
#       stars                                               text  useful  \
# 1         5  I love this place! My fiance And I go here atl...       0
# 2         1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 4         5  Delicious healthy food. The steak is amazing. ...       0
# 5         1  This place sucks. The customer service is horr...       2
# 10        5  I have been an Emerald Club member for a numbe...       0
# ...     ...                                                ...     ...
# 689       5  Came here with my 2 year old daughter for our ...       2
# 4874      5  Great little restaurant. Not to many tables an...       0
# 564       5  Always great friendly service and fresh baked ...       0
# 3458      2  We were expecting amazing Thai food after all ...       1
# 4206      1  Sunday at 8p. Not many people here at all. We ...       0
#
#                      user_id  stars_squared  no_of_words
# 1     msQe1u7Z_XuqjGoqhB0J5g             25          317
# 2     msQe1u7Z_XuqjGoqhB0J5g              1          156
# 4     msQe1u7Z_XuqjGoqhB0J5g             25          165
# 5     msQe1u7Z_XuqjGoqhB0J5g              1          467
# 10    TlvV-xJhmh7LCwJYXkV-cg             25          185
# ...                      ...            ...          ...
# 689   q3AiAe-AcpDrNsdZf8nCvQ             25          315
# 4874  NJxaA7q9BhqaDrFpfR2Jeg             25          232
# 564   kBNFdviedCPFWyR-wVaAzw             25          444
# 3458  PkRFSQgSfca9Tamq7b2LdQ              4          993
# 4206  ic9zIsm7zoxUm3Axyegx8g              1          221
#
# [2610 rows x 11 columns]

# %% [markdown]
# ## Rewrite the following as a lambda function
#
# Create a new column `'Review_Length'` by applying this lambda function to the `'Review_num_words'` column.

# %%
# Rewrite the following function as a lambda function
def rewrite_as_lambda(value):
    if len(value) < 50:
        return 'Short'
    elif len(value) < 80:
        return 'Medium'
    else:
        return 'Long'
# Hint: nest your if, else conditionals

df['Review_length'] = df['text'].map(lambda x : 
                                     'short' if len(x.strip()) < 50
                                                   else 'medium' if len(x.strip()) < 80
                                                   else 'long')

# %%
df.head(20)
# Out:
#                business_id  cool        date  funny               review_id  \
# 1   pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13      0  dDl8zu1vWPdKGihJrwQbpw
# 2   jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23      1  LZp4UX5zK3e-c5ZGSeo3kA
# 4   Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05      0  jsDu6QEJHbwP2Blom1PLCA
# 5   vgfcTvK81oD4r50NMjU2Ag     0  2011-02-25      0  pfavA0hr3nyqO61oupj-lA
# 10  yFumR3CWzpfvTH2FCthvVw     0  2016-06-15      0  STiFMww2z31siPY7BWNC2g
# 11  UBv8heCQR0RPnUQG0zkXIQ     0  2016-09-23      0  HkYqGb0Gplmmk-xlHTRBoA
# 12  hdgYnadxg0GANhWOJabr2g     0  2014-08-23      0  RgqWdZA4xR023iP3T6jVfA
# 19  gZGsReG0VeX4uKViHTB9EQ     0  2017-08-16      0  51RHs_V_fjuistnuKxNpEg
# 25  f-v1fvtnbdw_QQRsCnwH-g     0  2017-11-18      0  alI_kRKyEHfdHibYGgtJbw
# 26  yz66FIUPDKGhILDWzRLeKg     0  2017-11-18      0  85DRIjwPJOTb4q0qOlBstw
# 27  6qDRqHWqf0EeHupSUEBfKg     0  2015-12-10      0  GbiLIKmQPVCBtdNkTVdVSA
# 28  7AlULGZI1pHt0imODsqdkg     0  2012-02-12      0  UaHgsL0xS4UnJ_iKqeOk_w
# 29  th4pZ5LkoIIkb1Vmu_m2DA     0  2012-02-12      0  c4zzAD1S6721Fh-acCBy-g
# 30  nsSfCKW9KDB4COj9bzXApw     0  2012-02-12      0  TTBwocu2mvqJFJrwmJN0Sw
# 31  cP8ErpZfRzdVR5Fvks-pnQ     0  2012-02-12      0  -CresnnXQSHrQ85Ogm-Pqw
# 32  Edr6SafmQrZa6CcFuItoqg     0  2014-06-03      0  U04YgYr4PiGUxB46J4xapg
# 35  SpJYus_184M2TdT7t52rIA     0  2016-11-18      0  s9cpVj40VR_yl0lXbZQe6w
# 40  qdC2h3MqCNussc5lhzL7gg     0  2015-11-05      0  AJ0IglpYAp2D0daOlVGIdg
# 41  XgRDG9E_WLEbl8S-QUqQkQ     0  2015-11-05      0  5D_MsAJHrMa8QKkpE3g1Sg
# 42  awgoBwuhzlLGKEIverTGjQ     0  2017-01-21      0  5bWN_IN8MQGjJ6_ZIXffDw
#
#     stars                                               text  useful  \
# 1       5  I love this place! My fiance And I go here atl...       0
# 2       1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 4       5  Delicious healthy food. The steak is amazing. ...       0
# 5       1  This place sucks. The customer service is horr...       2
# 10      5  I have been an Emerald Club member for a numbe...       0
# 11      1  The score should be negative. Its HORRIBLE. Th...       0
# 12      5  I went there twice and I am pretty happy with ...       0
# 19      5  Finally! After trying many Mexican restaurants...       0
# 25      1  I have to write a review on the Fractured Prun...       0
# 26      1  I wish i could tell you all about the food but...       1
# 27      5  Wonderful! One of my favorite places. BBQ is e...       0
# 28      5  The price is about the same as Quizinos. The s...       0
# 29      4  The food was ok. You get a lot of food for the...       0
# 30      5  The staff were friendly and helpful. The food ...       1
# 31      5  The staff were very helpful. We painted potter...       0
# 32      2  Limited vegetarian options. Ordered Greek sala...       0
# 35      5  I trust my vehicles here. Comparable prices. M...       0
# 40      1  This place doesn't even deserve 1 star. Horrib...      18
# 41      5  The butter burger was cooked perfectly and jui...       0
# 42      5  Best location ever! I love love love the manag...       0
#
#                    user_id  stars_squared  no_of_words Review_length
# 1   msQe1u7Z_XuqjGoqhB0J5g             25          317          long
# 2   msQe1u7Z_XuqjGoqhB0J5g              1          156          long
# 4   msQe1u7Z_XuqjGoqhB0J5g             25          165          long
# 5   msQe1u7Z_XuqjGoqhB0J5g              1          467          long
# 10  TlvV-xJhmh7LCwJYXkV-cg             25          185          long
# 11  NhOc64RsrTT1Dls50yYW8g              1          280          long
# 12  NhOc64RsrTT1Dls50yYW8g             25          117          long
# 19  5ngpW5tf3ep680eG1HxHzA             25          403          long
# 25  Fc_nb6N6Sdurqb-rwsY1Bw              1          644          long
# 26  Fc_nb6N6Sdurqb-rwsY1Bw              1          574          long
# 27  G22ITfVETYHtIhnn5lLRrQ             25          110          long
# 28  FjH3TH8OvHGLNEbzdEYlNg             25          139          long
# 29  FjH3TH8OvHGLNEbzdEYlNg             16           84          long
# 30  FjH3TH8OvHGLNEbzdEYlNg             25           93          long
# 31  FjH3TH8OvHGLNEbzdEYlNg             25          137          long
# 32  B7Fh30KQT1xPSGt_pIhRRA              4          199          long
# 35  zx_Op2OAOM_fRic9tU-jqA             25          176          long
# 40  Ka7TIp74VHSa90rfdg4_2g              1          286          long
# 41  Ka7TIp74VHSa90rfdg4_2g             25          142          long
# 42  yyPHK6khPa4-ErV9U32x3A             25          244          long

# %% [markdown]
# ## Level Up: Dates Advanced
# <img src="images/world_map.png" width="600">
#
# Print the first five rows of the `'date'` column.

# %%
# Your code here
df['date'].head()
# Out:
# 1     2012-11-13
# 2     2014-10-23
# 4     2014-09-05
# 5     2011-02-25
# 10    2016-06-15
# Name: date, dtype: object

# %% [markdown]
# Overwrite the `'date'` column by reordering the month and day from `YYYY-MM-DD` to `DD-MM-YYYY`. Try to do this using a lambda function.

# %%
# Your code here
df['date'] = pd.to_datetime(df['date']).dt.strftime('%d-%m-%Y')

# %%
df.head()
# Out:
#                business_id  cool        date  funny               review_id  \
# 1   pomGBqfbxcqPv14c3XH-ZQ     0  13-11-2012      0  dDl8zu1vWPdKGihJrwQbpw
# 2   jtQARsP6P-LbkyjbO1qNGg     1  23-10-2014      1  LZp4UX5zK3e-c5ZGSeo3kA
# 4   Ums3gaP2qM3W1XcA5r6SsQ     0  05-09-2014      0  jsDu6QEJHbwP2Blom1PLCA
# 5   vgfcTvK81oD4r50NMjU2Ag     0  25-02-2011      0  pfavA0hr3nyqO61oupj-lA
# 10  yFumR3CWzpfvTH2FCthvVw     0  15-06-2016      0  STiFMww2z31siPY7BWNC2g
#
#     stars                                               text  useful  \
# 1       5  I love this place! My fiance And I go here atl...       0
# 2       1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 4       5  Delicious healthy food. The steak is amazing. ...       0
# 5       1  This place sucks. The customer service is horr...       2
# 10      5  I have been an Emerald Club member for a numbe...       0
#
#                    user_id  stars_squared  no_of_words Review_length
# 1   msQe1u7Z_XuqjGoqhB0J5g             25          317          long
# 2   msQe1u7Z_XuqjGoqhB0J5g              1          156          long
# 4   msQe1u7Z_XuqjGoqhB0J5g             25          165          long
# 5   msQe1u7Z_XuqjGoqhB0J5g              1          467          long
# 10  TlvV-xJhmh7LCwJYXkV-cg             25          185          long

# %% [markdown]
# ## Summary
#
# Hopefully, you're getting the hang of lambda functions now! It's important not to overuse them - it will often make more sense to define a function so that it's reusable elsewhere. But whenever you need to quickly apply some simple processing to a collection of data you have a new technique that will help you to do just that. It'll also be useful if you're reading someone else's code that happens to use lambdas.
